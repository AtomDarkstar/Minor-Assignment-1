# %%
import random

Age = []
for i in range(1000):
    age = random.randint(60,70)
    Age.append(age);
Age
# Out:
# [64,
#  69,
#  69,
#  69,
#  60,
#  70,
#  61,
#  69,
#  62,
#  67,
#  68,
#  70,
#  67,
#  67,
#  68,
#  68,
#  64,
#  62,
#  66,
#  61,
#  63,
#  60,
#  63,
#  62,
#  65,
#  67,
#  65,
#  61,
#  61,
#  67,
#  64,
#  60,
#  61,
#  60,
#  62,
#  62,
#  65,
#  69,
#  67,
#  68,
#  60,
#  70,
#  69,
#  67,
#  64,
#  64,
#  70,
#  67,
#  62,
#  70,
#  62,
#  70,
#  62,
#  64,
#  68,
#  68,
#  69,
#  69,
#  60,
#  67,
#  67,
#  68,
#  60,
#  62,
#  63,
#  70,
#  61,
#  67,
#  70,
#  65,
#  62,
#  67,
#  64,
#  67,
#  60,
#  65,
#  64,
#  67,
#  68,
#  64,
#  60,
#  70,
#  69,
#  61,
#  60,
#  65,
#  64,
#  62,
#  65,
#  65,
#  61,
#  69,
#  64,
#  64,
#  62,
#  67,
#  67,
#  62,
#  63,
#  62,
#  62,
#  68,
#  70,
#  64,
#  61,
#  60,
#  62,
#  61,
#  60,
#  67,
#  66,
#  65,
#  61,
#  65,
#  66,
#  70,
#  66,
#  65,
#  62,
#  61,
#  66,
#  65,
#  61,
#  60,
#  69,
#  70,
#  60,
#  61,
#  70,
#  70,
#  61,
#  64,
#  70,
#  70,
#  60,
#  64,
#  68,
#  70,
#  60,
#  62,
#  68,
#  65,
#  65,
#  60,
#  69,
#  65,
#  66,
#  70,
#  69,
#  66,
#  67,
#  62,
#  62,
#  64,
#  66,
#  60,
#  65,
#  67,
#  61,
#  61,
#  61,
#  69,
#  68,
#  66,
#  61,
#  66,
#  69,
#  67,
#  65,
#  67,
#  62,
#  65,
#  68,
#  70,
#  63,
#  63,
#  66,
#  69,
#  66,
#  62,
#  60,
#  68,
#  60,
#  69,
#  63,
#  62,
#  61,
#  66,
#  70,
#  65,
#  62,
#  61,
#  62,
#  63,
#  67,
#  67,
#  66,
#  68,
#  65,
#  60,
#  63,
#  63,
#  67,
#  61,
#  67,
#  62,
#  64,
#  70,
#  68,
#  66,
#  69,
#  67,
#  64,
#  62,
#  67,
#  68,
#  60,
#  63,
#  69,
#  61,
#  63,
#  70,
#  68,
#  69,
#  69,
#  61,
#  70,
#  68,
#  64,
#  61,
#  63,
#  60,
#  61,
#  69,
#  68,
#  64,
#  70,
#  60,
#  66,
#  60,
#  66,
#  62,
#  61,
#  69,
#  61,
#  67,
#  68,
#  60,
#  69,
#  66,
#  65,
#  70,
#  64,
#  68,
#  69,
#  69,
#  60,
#  61,
#  63,
#  60,
#  66,
#  65,
#  61,
#  61,
#  67,
#  60,
#  64,
#  69,
#  68,
#  60,
#  62,
#  60,
#  67,
#  69,
#  64,
#  67,
#  65,
#  68,
#  68,
#  65,
#  66,
#  66,
#  65,
#  63,
#  68,
#  61,
#  61,
#  62,
#  65,
#  61,
#  70,
#  66,
#  63,
#  65,
#  62,
#  61,
#  65,
#  68,
#  64,
#  63,
#  70,
#  61,
#  60,
#  69,
#  66,
#  63,
#  65,
#  61,
#  67,
#  69,
#  60,
#  63,
#  63,
#  60,
#  64,
#  65,
#  69,
#  63,
#  63,
#  70,
#  66,
#  62,
#  66,
#  62,
#  63,
#  60,
#  65,
#  66,
#  70,
#  60,
#  68,
#  64,
#  65,
#  68,
#  66,
#  69,
#  64,
#  69,
#  64,
#  65,
#  61,
#  67,
#  61,
#  63,
#  70,
#  64,
#  61,
#  70,
#  67,
#  62,
#  63,
#  66,
#  70,
#  68,
#  70,
#  61,
#  68,
#  63,
#  61,
#  65,
#  67,
#  65,
#  69,
#  67,
#  67,
#  62,
#  61,
#  65,
#  64,
#  65,
#  60,
#  63,
#  64,
#  67,
#  68,
#  60,
#  67,
#  70,
#  68,
#  67,
#  68,
#  68,
#  68,
#  61,
#  66,
#  64,
#  68,
#  63,
#  62,
#  66,
#  61,
#  67,
#  70,
#  65,
#  64,
#  65,
#  64,
#  68,
#  61,
#  63,
#  69,
#  62,
#  66,
#  64,
#  68,
#  69,
#  63,
#  63,
#  64,
#  68,
#  66,
#  63,
#  64,
#  67,
#  68,
#  60,
#  60,
#  64,
#  63,
#  64,
#  60,
#  63,
#  68,
#  69,
#  63,
#  60,
#  65,
#  64,
#  64,
#  70,
#  65,
#  66,
#  61,
#  65,
#  70,
#  66,
#  63,
#  67,
#  69,
#  68,
#  66,
#  60,
#  69,
#  66,
#  60,
#  66,
#  63,
#  65,
#  67,
#  60,
#  61,
#  64,
#  66,
#  67,
#  62,
#  63,
#  65,
#  66,
#  66,
#  65,
#  69,
#  65,
#  68,
#  61,
#  62,
#  63,
#  64,
#  64,
#  61,
#  60,
#  69,
#  63,
#  63,
#  66,
#  63,
#  70,
#  68,
#  63,
#  68,
#  60,
#  62,
#  62,
#  65,
#  60,
#  70,
#  62,
#  64,
#  60,
#  70,
#  60,
#  65,
#  68,
#  67,
#  67,
#  64,
#  60,
#  69,
#  66,
#  65,
#  69,
#  68,
#  61,
#  63,
#  68,
#  66,
#  67,
#  68,
#  64,
#  60,
#  64,
#  61,
#  68,
#  65,
#  68,
#  61,
#  69,
#  70,
#  70,
#  66,
#  67,
#  69,
#  69,
#  69,
#  68,
#  61,
#  69,
#  67,
#  63,
#  60,
#  70,
#  68,
#  69,
#  62,
#  60,
#  69,
#  62,
#  64,
#  62,
#  63,
#  65,
#  69,
#  65,
#  66,
#  65,
#  69,
#  61,
#  67,
#  66,
#  63,
#  61,
#  62,
#  60,
#  67,
#  61,
#  63,
#  69,
#  67,
#  65,
#  64,
#  67,
#  62,
#  63,
#  64,
#  68,
#  64,
#  66,
#  65,
#  66,
#  67,
#  69,
#  66,
#  68,
#  70,
#  63,
#  61,
#  61,
#  62,
#  68,
#  69,
#  68,
#  68,
#  70,
#  68,
#  62,
#  62,
#  63,
#  64,
#  70,
#  62,
#  62,
#  64,
#  60,
#  69,
#  66,
#  62,
#  66,
#  62,
#  67,
#  60,
#  61,
#  68,
#  67,
#  61,
#  67,
#  67,
#  61,
#  69,
#  65,
#  67,
#  64,
#  68,
#  70,
#  61,
#  67,
#  63,
#  67,
#  66,
#  67,
#  69,
#  61,
#  70,
#  70,
#  69,
#  65,
#  70,
#  61,
#  68,
#  64,
#  66,
#  67,
#  66,
#  65,
#  62,
#  70,
#  69,
#  66,
#  70,
#  69,
#  64,
#  63,
#  64,
#  67,
#  64,
#  69,
#  65,
#  68,
#  68,
#  60,
#  68,
#  64,
#  67,
#  62,
#  62,
#  68,
#  65,
#  61,
#  66,
#  62,
#  60,
#  65,
#  68,
#  68,
#  61,
#  61,
#  70,
#  61,
#  60,
#  70,
#  61,
#  61,
#  69,
#  60,
#  64,
#  65,
#  63,
#  70,
#  61,
#  60,
#  63,
#  66,
#  70,
#  69,
#  69,
#  66,
#  65,
#  65,
#  66,
#  62,
#  69,
#  69,
#  68,
#  68,
#  60,
#  60,
#  61,
#  63,
#  61,
#  61,
#  65,
#  64,
#  69,
#  68,
#  67,
#  62,
#  61,
#  64,
#  66,
#  68,
#  63,
#  65,
#  67,
#  63,
#  65,
#  67,
#  63,
#  68,
#  63,
#  69,
#  66,
#  64,
#  66,
#  65,
#  63,
#  68,
#  60,
#  66,
#  63,
#  64,
#  69,
#  61,
#  64,
#  67,
#  63,
#  69,
#  64,
#  65,
#  62,
#  63,
#  68,
#  60,
#  66,
#  70,
#  70,
#  65,
#  69,
#  61,
#  69,
#  61,
#  67,
#  63,
#  68,
#  69,
#  60,
#  66,
#  69,
#  68,
#  60,
#  63,
#  67,
#  60,
#  70,
#  61,
#  67,
#  61,
#  64,
#  62,
#  65,
#  70,
#  69,
#  69,
#  70,
#  62,
#  70,
#  65,
#  60,
#  64,
#  62,
#  61,
#  60,
#  68,
#  64,
#  69,
#  65,
#  68,
#  61,
#  61,
#  69,
#  66,
#  66,
#  65,
#  64,
#  65,
#  61,
#  65,
#  61,
#  66,
#  66,
#  60,
#  69,
#  64,
#  60,
#  66,
#  70,
#  64,
#  65,
#  68,
#  63,
#  65,
#  64,
#  60,
#  64,
#  70,
#  68,
#  61,
#  62,
#  66,
#  61,
#  68,
#  63,
#  65,
#  69,
#  65,
#  67,
#  61,
#  60,
#  61,
#  68,
#  64,
#  63,
#  70,
#  65,
#  68,
#  68,
#  69,
#  60,
#  66,
#  64,
#  64,
#  69,
#  63,
#  70,
#  63,
#  60,
#  67,
#  68,
#  66,
#  68,
#  64,
#  62,
#  68,
#  69,
#  66,
#  68,
#  63,
#  66,
#  61,
#  69,
#  69,
#  61,
#  67,
#  67,
#  66,
#  69,
#  68,
#  61,
#  62,
#  70,
#  66,
#  61,
#  64,
#  61,
#  62,
#  70,
#  62,
#  64,
#  66,
#  65,
#  64,
#  69,
#  67,
#  65,
#  61,
#  60,
#  67,
#  63,
#  63,
#  63,
#  63,
#  62,
#  66,
#  61,
#  60,
#  67,
#  67,
#  69,
#  60,
#  70,
#  61,
#  65,
#  60,
#  63,
#  65,
#  70,
#  68,
#  65,
#  67,
#  62,
#  61,
#  70,
#  64,
#  60,
#  65,
#  70,
#  66,
#  69,
#  64,
#  70,
#  62,
#  68,
#  61,
#  67,
#  70,
#  64,
#  65,
#  62,
#  61,
#  69,
#  65,
#  69,
#  68,
#  70,
#  63,
#  69,
#  69,
#  61,
#  60,
#  61,
#  63,
#  62,
#  67,
#  70,
#  68,
#  61,
#  62,
#  64,
#  67,
#  69,
#  65,
#  61,
#  67,
#  64,
#  69,
#  60,
#  69,
#  70,
#  69,
#  61,
#  65,
#  66,
#  62,
#  60,
#  69,
#  69,
#  63,
#  62,
#  68,
#  68,
#  63,
#  70,
#  65,
#  62,
#  62,
#  70,
#  64,
#  68,
#  69,
#  64,
#  62,
#  70,
#  65,
#  60,
#  62,
#  60,
#  61,
#  70,
#  66,
#  70,
#  60,
#  68,
#  70,
#  70,
#  70,
#  66,
#  64,
#  68,
#  64,
#  62,
#  63,
#  62,
#  68]

# %%
import numpy as np

Age = np.array(Age)


mean = np.mean(age)
std= np.std(Age)
mean,std
# Out:
# (68.0, 3.1866557705531986)

# %%
import matplotlib.pyplot as plt

plt.hist(Age,bins= 22)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Frequency chart of ages")
plt.show()

# %%
'''In this case, since we 
generated the ages randomly from a uniform
distribution between 60 and 70, the
distribution of ages should be
approximately uniform, and thus not normal.'''
# Out:
# 'In this case, since we \ngenerated the ages randomly from a uniform\ndistribution between 60 and 70, the\ndistribution of ages should be\napproximately uniform, and thus not normal.'

# %%
sample= np.random.choice(Age,size = 30)

# %%
s_mean = []
s_mean.append(np.mean(sample))
s_mean
# Out:
# [65.16666666666667]

# %%
for i in range(0,499):
    sample= np.random.choice(Age,size = 30)
    s_mean.append(np.mean(sample))

# %%
np.size(s_mean)
# Out:
# 500

# %%
plt.hist(s_mean,bins=20)
plt.xlabel("sample mean")
plt.ylabel("frequency")
plt.title("Frequecy vs sample_mean")
# Out:
# Text(0.5, 1.0, 'Frequecy vs sample_mean')

# %%
s_mean = np.array(s_mean)
np.mean(s_mean),np.std(s_mean)
# Out:
# (65.03040000000001, 0.5399632250852314)

# %%
np.mean(s_mean),mean
# Out:
# (65.03040000000001, 68.0)

# %%
#its not exactly the same but nearly

# %%
np.std(s_mean),std/(30**0.5)
# Out:
# (0.5399632250852314, 0.5818010828453313)

# %%
#Again, its not exactly the same but similar

# %%
#Repeatingt he entire process with sample size 50

# %%
sample= np.random.choice(Age,size = 50)
s_mean = []
s_mean.append(np.mean(sample))
s_mean
# Out:
# [65.14]

# %%
for i in range(0,499):
    sample= np.random.choice(Age,size = 50)
    s_mean.append(np.mean(sample))

# %%
plt.hist(s_mean,bins=15)
plt.xlabel("sample mean")
plt.ylabel("frequency")
plt.title("Frequecy vs sample_mean")
# Out:
# Text(0.5, 1.0, 'Frequecy vs sample_mean')

# %%
s_mean = np.array(s_mean)
np.mean(s_mean),np.std(s_mean)
# Out:
# (65.03964, 0.4496672885589967)

# %%
np.mean(s_mean),mean
# Out:
# (65.03964, 68.0)

# %%
np.std(s_mean),std/(50**0.5)
# Out:
# (0.4496672885589967, 0.4506611809330819)

# %%
#again the resuslts are better than 30 asmple size
